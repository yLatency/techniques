# %%
from itertools import combinations
from functools import reduce
from pyspark.sql.functions import col, when, concat, concat_ws, collect_list
from pyspark.sql.types import StringType
import pickle
import random

# %%
traces =(spark.read.option('mergeSchema', 'true')
              .parquet('data/14-11-18*.parquet'))

# %%
frontend = 'web-service_HomeControllerHome_avg_dur'

backends = [c for c in traces.columns
        if c !='traceId' and c.endswith('avg_self_dur')]

# %%
frontendSLA = traces.approxQuantile([frontend], [0.99],0)[0][0]

# %%
maxs ={ c : traces.select(c).rdd.max()[0]
        for c in backends }
mins ={ c : traces.select(c).rdd.min()[0]
        for c in backends }

# %%
normalizedTrace = reduce(lambda df, c : df.withColumn(c, (col(c) - mins[c])/(maxs[c] - mins[c])),
                        backends,
                        traces)

# %%
from sklearn.metrics import precision_recall_curve

thresholdsDict = {}
y = [1 if row[0]>frontendSLA else 0
     for row in traces.select(frontend).collect()]

for aBackend in backends:
    scores = [row[0] for row in normalizedTrace.select(aBackend).collect()]
    _, _, thresholds = precision_recall_curve(y, scores)
    thresholdsDict[aBackend] = thresholds

# %%
k = 27
for aBackend in backends:
    thresholdsDict[aBackend] = thresholdsDict[aBackend][:k]

# %%
k=10
for aBackend in backends:
    stepSize = len(thresholdsDict[aBackend])//k
    thresholdsDict[aBackend] = thresholdsDict[aBackend][::stepSize]

# %%
def withColumnsTpFp(df, indexThresholdPair):
        i, t = indexThresholdPair
        return (df.withColumn('tp-%d'% i,
                              when((col(aBackend)>= t) & (col(frontend)>frontendSLA), '1')
                              .otherwise('0'))
                  .withColumn('fp-%d'% i,
                              when((col(aBackend)>= t) & (col(frontend)<=frontendSLA), '1')
                              .otherwise('0')))

# %%
# %%time
cache = {}
for aBackend in backends:
    df = reduce(withColumnsTpFp,
                enumerate(thresholdsDict[aBackend]),
                normalizedTrace)

    aggs = [concat_ws("",collect_list(col('tp-%d' % i))).alias('tp-%d' % i)
                      for i, t in enumerate(thresholdsDict[aBackend])]

    aggs += [concat_ws("",collect_list(col('fp-%d' % i))).alias('fp-%d' % i)
                      for i, t in enumerate(thresholdsDict[aBackend])]

    res=df.groupBy().agg(*aggs).collect()[0]
    for i in range(len(thresholdsDict[aBackend])):
        tpBit, fpBit = res['tp-%d'%i], res['fp-%d'%i]
        cache[aBackend, i] = int(tpBit, 2),int(fpBit, 2)
# Out:
# CPU times: user 821 ms, sys: 229 ms, total: 1.05 s
# Wall time: 10.6 s

# %%
posCount = normalizedTrace.filter(col(frontend)> frontendSLA).count()

def computePrecRec(chromosome):
    backendAndThresholds = [(b, t)
                            for b, t in zip(backends, chromosome)]
    tpBit = reduce(lambda bits,bt : bits & cache[bt][0] ,
                   backendAndThresholds[1:],
                   cache[backendAndThresholds[0]][0])
    fpBit = reduce(lambda bits,bt  : bits & cache[bt][1] ,
                    backendAndThresholds[1:],
                    cache[backendAndThresholds[0]][1])
    truePosCount = bin(tpBit).count("1")
    falsePosCount = bin(fpBit).count("1")
    retreived = (truePosCount + falsePosCount) 
    precision = truePosCount/retreived if retreived > 0 else 0
    recall = truePosCount/posCount
    
    return precision, recall

# %%
def computeFMeasure(chromosome):
    precision, recall = computePrecRec(chromosome)
    return 2*(precision*recall)/(precision+recall) if precision > 0 or recall > 0 else 0

# %%
import random, copy
from deap import base, creator, tools, algorithms

# %%
creator.create("Fitness", base.Fitness, weights=(1.0,1.0))
evaluate = lambda ind: computePrecRec(ind)
selection = {'function':tools.selNSGA2}

# %%
creator.create("Fitness", base.Fitness, weights=(1.0,))
evaluate = lambda ind: (computeFMeasure(ind),)
selection = {'function':tools.selTournament, 'tournsize':3}

# %%
creator.create("Fitness", base.Fitness, weights=(1.0,1.0))
evaluate = lambda ind: (computeFMeasure(ind), ind.count(0))
selection = {'function':tools.selNSGA2}
# Out:
# /home/luca/environments/spark/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Fitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %%
creator.create("Fitness", base.Fitness, weights=(1.0,1.0,1.0))
evaluate = lambda ind: (*computePrecRec(ind),ind.count(0))
selection = {'function':tools.selNSGA2}
# Out:
# /home/luca/environments/spark/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Fitness' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %%
creator.create("Individual", list, fitness=creator.Fitness)
toolbox = base.Toolbox()

# %%
for aBackend in backends:
    toolbox.register(aBackend,
                     lambda a, b: 0, #random.randint,
                     0,
                     len(thresholdsDict[aBackend])-1 )

# %%
toolbox.register("individual",
                 tools.initCycle,
                 creator.Individual,
                 tuple(toolbox.__dict__[b] for b in backends))

toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate",
                 tools.mutUniformInt,
                 low = [0]*len(backends),
                 up = [len(thresholdsDict[b]) - 1
                       for b in backends],
                 indpb = 1.0/len(backends))

# %%
toolbox.register("select", **selection)
toolbox.register("evaluate", evaluate)

# %%
toolbox.pop_size = 100
toolbox.max_gen = 200
toolbox.mut_prob = 0.2

# %%
def runEA(toolbox, stats=None, verbose=False):
    pop = toolbox.population(n=toolbox.pop_size)
    pop = toolbox.select(pop, len(pop))
    return algorithms.eaMuPlusLambda(pop, toolbox, mu=toolbox.pop_size, 
                                     lambda_=toolbox.pop_size, 
                                     cxpb=1-toolbox.mut_prob,
                                     mutpb=toolbox.mut_prob, 
                                     stats=stats, 
                                     ngen=toolbox.max_gen, 
                                     verbose=verbose)

# %%
res, _ = runEA(toolbox)

# %%
def denormalize(ind):
    return [(thresholdsDict[b][t] *(maxs[b] - mins[b]) + mins[b], b.split('_')[1].replace('avg_self_dur', ''))
            for t, b in zip(ind, backends) if t>0]

# %%
solutions = sorted([(computeFMeasure(ind), *computePrecRec(ind), denormalize(ind)) for ind in res],
                    key=lambda x:x[0])

for f, prec, rec, sol in solutions:
    print (sol)
    print('F-score: ',f)
    print('Precision:',prec, '\t Recall: ', rec, '\n\n')
# Out:
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# []
# F-score:  0.029766382693207003
# Precision: 0.01510804730552517 	 Recall:  1.0
#
#
# [(191400.0, 'HomeControllerHome')]
# F-score:  0.0317481256733285
# Precision: 0.01613371768228643 	 Recall:  0.9863387978142076
#
#
# [(191400.0, 'HomeControllerHome')]
# F-score:  0.0317481256733285
# Precision: 0.01613371768228643 	 Recall:  0.9863387978142076
#
#
# [(197918.0, 'HomeControllerHome')]
# F-score:  0.0355097081359883
# Precision: 0.01808309129940649 	 Recall:  0.9781420765027322
#
#
# [(197918.0, 'HomeControllerHome')]
# F-score:  0.0355097081359883
# Precision: 0.01808309129940649 	 Recall:  0.9781420765027322
#
#
# [(203660.0, 'HomeControllerHome')]
# F-score:  0.04165691551603089
# Precision: 0.021284228147793852 	 Recall:  0.9726775956284153
#
#
# [(203660.0, 'HomeControllerHome')]
# F-score:  0.04165691551603089
# Precision: 0.021284228147793852 	 Recall:  0.9726775956284153
#
#
# [(209658.0, 'HomeControllerHome')]
# F-score:  0.04995381226462019
# Precision: 0.025643831618880862 	 Recall:  0.9603825136612022
#
#
# [(209658.0, 'HomeControllerHome')]
# F-score:  0.04995381226462019
# Precision: 0.025643831618880862 	 Recall:  0.9603825136612022
#
#
# [(1852800.0, 'ItemsControllerFinditemsrandombyidproduct')]
# F-score:  0.058355437665782495
# Precision: 1.0 	 Recall:  0.030054644808743168
#
#
# [(1852800.0, 'ItemsControllerFinditemsrandombyidproduct')]
# F-score:  0.058355437665782495
# Precision: 1.0 	 Recall:  0.030054644808743168
#
#
# [(216389.0, 'HomeControllerHome')]
# F-score:  0.061899679829242264
# Precision: 0.031991174848317705 	 Recall:  0.9508196721311475
#
#
# [(216389.0, 'HomeControllerHome')]
# F-score:  0.061899679829242264
# Precision: 0.031991174848317705 	 Recall:  0.9508196721311475
#
#
# [(223921.0, 'HomeControllerHome')]
# F-score:  0.08051267113311972
# Precision: 0.042049534473315886 	 Recall:  0.9439890710382514
#
#
# [(223921.0, 'HomeControllerHome')]
# F-score:  0.08051267113311972
# Precision: 0.042049534473315886 	 Recall:  0.9439890710382514
#
#
# [(709000.0, 'ItemsControllerFinditemsrandombyidproduct')]
# F-score:  0.09067357512953367
# Precision: 0.875 	 Recall:  0.04781420765027322
#
#
# [(709000.0, 'ItemsControllerFinditemsrandombyidproduct')]
# F-score:  0.09067357512953367
# Precision: 0.875 	 Recall:  0.04781420765027322
#
#
# [(4200.0, 'get'), (7000.0, 'ItemsControllerFindfeaturesitemrandom'), (232886.0, 'HomeControllerHome')]
# F-score:  0.09523809523809523
# Precision: 0.4482758620689655 	 Recall:  0.05327868852459016
#
#
# [(4200.0, 'get'), (7000.0, 'ItemsControllerFindfeaturesitemrandom'), (232886.0, 'HomeControllerHome')]
# F-score:  0.09523809523809523
# Precision: 0.4482758620689655 	 Recall:  0.05327868852459016
#
#
# [(232886.0, 'HomeControllerHome')]
# F-score:  0.109270468302007
# Precision: 0.05801759133964817 	 Recall:  0.9371584699453552
#
#
# [(232886.0, 'HomeControllerHome')]
# F-score:  0.109270468302007
# Precision: 0.05801759133964817 	 Recall:  0.9371584699453552
#
#
# [(3000.0, 'get'), (7000.0, 'ItemsControllerFindfeaturesitemrandom'), (197918.0, 'HomeControllerHome')]
# F-score:  0.15523059617547805
# Precision: 0.4394904458598726 	 Recall:  0.0942622950819672
#
#
# [(3000.0, 'get'), (7000.0, 'ItemsControllerFindfeaturesitemrandom'), (197918.0, 'HomeControllerHome')]
# F-score:  0.15523059617547805
# Precision: 0.4394904458598726 	 Recall:  0.0942622950819672
#
#
# [(3000.0, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (232886.0, 'HomeControllerHome')]
# F-score:  0.28415300546448086
# Precision: 0.4262295081967213 	 Recall:  0.21311475409836064
#
#
# [(3000.0, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (232886.0, 'HomeControllerHome')]
# F-score:  0.28415300546448086
# Precision: 0.4262295081967213 	 Recall:  0.21311475409836064
#
#
# [(4000.0, 'ItemsControllerFindfeaturesitemrandom'), (246462.0, 'HomeControllerHome')]
# F-score:  0.3240058910162003
# Precision: 0.3514376996805112 	 Recall:  0.3005464480874317
#
#
# [(4000.0, 'ItemsControllerFindfeaturesitemrandom'), (246462.0, 'HomeControllerHome')]
# F-score:  0.3240058910162003
# Precision: 0.3514376996805112 	 Recall:  0.3005464480874317
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (276232.0, 'HomeControllerHome')]
# F-score:  0.33087633087633084
# Precision: 0.4130879345603272 	 Recall:  0.27595628415300544
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (276232.0, 'HomeControllerHome')]
# F-score:  0.33087633087633084
# Precision: 0.4130879345603272 	 Recall:  0.27595628415300544
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (246462.0, 'HomeControllerHome')]
# F-score:  0.33655394524959736
# Precision: 0.40980392156862744 	 Recall:  0.2855191256830601
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (246462.0, 'HomeControllerHome')]
# F-score:  0.33655394524959736
# Precision: 0.40980392156862744 	 Recall:  0.2855191256830601
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom')]
# F-score:  0.33941316415543216
# Precision: 0.4045368620037807 	 Recall:  0.2923497267759563
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom')]
# F-score:  0.33941316415543216
# Precision: 0.4045368620037807 	 Recall:  0.2923497267759563
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (232886.0, 'HomeControllerHome')]
# F-score:  0.3402555910543131
# Precision: 0.4096153846153846 	 Recall:  0.29098360655737704
#
#
# [(1800.0000000000002, 'get'), (4000.0, 'ItemsControllerFindfeaturesitemrandom'), (232886.0, 'HomeControllerHome')]
# F-score:  0.3402555910543131
# Precision: 0.4096153846153846 	 Recall:  0.29098360655737704
#
#
# [(4200.0, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.3521505376344086
# Precision: 0.34656084656084657 	 Recall:  0.35792349726775957
#
#
# [(4200.0, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.3521505376344086
# Precision: 0.34656084656084657 	 Recall:  0.35792349726775957
#
#
# [(1800.0000000000002, 'get')]
# F-score:  0.3674892703862661
# Precision: 0.22863818424566087 	 Recall:  0.9357923497267759
#
#
# [(1800.0000000000002, 'get')]
# F-score:  0.3674892703862661
# Precision: 0.22863818424566087 	 Recall:  0.9357923497267759
#
#
# [(1800.0000000000002, 'get'), (191400.0, 'HomeControllerHome')]
# F-score:  0.3694232861806311
# Precision: 0.23063858695652173 	 Recall:  0.9275956284153005
#
#
# [(1800.0000000000002, 'get'), (191400.0, 'HomeControllerHome')]
# F-score:  0.3694232861806311
# Precision: 0.23063858695652173 	 Recall:  0.9275956284153005
#
#
# [(1800.0000000000002, 'get'), (197918.0, 'HomeControllerHome')]
# F-score:  0.37489586226048327
# Precision: 0.23527361449982573 	 Recall:  0.9221311475409836
#
#
# [(1800.0000000000002, 'get'), (197918.0, 'HomeControllerHome')]
# F-score:  0.37489586226048327
# Precision: 0.23527361449982573 	 Recall:  0.9221311475409836
#
#
# [(1800.0000000000002, 'get'), (203660.0, 'HomeControllerHome')]
# F-score:  0.38181818181818183
# Precision: 0.24103299856527977 	 Recall:  0.9180327868852459
#
#
# [(1800.0000000000002, 'get'), (203660.0, 'HomeControllerHome')]
# F-score:  0.38181818181818183
# Precision: 0.24103299856527977 	 Recall:  0.9180327868852459
#
#
# [(1800.0000000000002, 'get'), (209658.0, 'HomeControllerHome')]
# F-score:  0.39132981839484476
# Precision: 0.24906785980611484 	 Recall:  0.912568306010929
#
#
# [(1800.0000000000002, 'get'), (209658.0, 'HomeControllerHome')]
# F-score:  0.39132981839484476
# Precision: 0.24906785980611484 	 Recall:  0.912568306010929
#
#
# [(1800.0000000000002, 'get'), (216389.0, 'HomeControllerHome')]
# F-score:  0.399157134256472
# Precision: 0.255984555984556 	 Recall:  0.9057377049180327
#
#
# [(1800.0000000000002, 'get'), (216389.0, 'HomeControllerHome')]
# F-score:  0.399157134256472
# Precision: 0.255984555984556 	 Recall:  0.9057377049180327
#
#
# [(1800.0000000000002, 'get'), (223921.0, 'HomeControllerHome')]
# F-score:  0.40979541227526345
# Precision: 0.2650360866078589 	 Recall:  0.9030054644808743
#
#
# [(1800.0000000000002, 'get'), (223921.0, 'HomeControllerHome')]
# F-score:  0.40979541227526345
# Precision: 0.2650360866078589 	 Recall:  0.9030054644808743
#
#
# [(1800.0000000000002, 'get'), (232886.0, 'HomeControllerHome')]
# F-score:  0.4199424736337488
# Precision: 0.27409261576971217 	 Recall:  0.8975409836065574
#
#
# [(1800.0000000000002, 'get'), (232886.0, 'HomeControllerHome')]
# F-score:  0.4199424736337488
# Precision: 0.27409261576971217 	 Recall:  0.8975409836065574
#
#
# [(1800.0000000000002, 'get'), (246462.0, 'HomeControllerHome')]
# F-score:  0.4274758252750917
# Precision: 0.2827525363917071 	 Recall:  0.8756830601092896
#
#
# [(1800.0000000000002, 'get'), (246462.0, 'HomeControllerHome')]
# F-score:  0.4274758252750917
# Precision: 0.2827525363917071 	 Recall:  0.8756830601092896
#
#
# [(3000.0, 'get'), (223921.0, 'HomeControllerHome')]
# F-score:  0.42795513373597927
# Precision: 0.31273644388398486 	 Recall:  0.6775956284153005
#
#
# [(3000.0, 'get'), (223921.0, 'HomeControllerHome')]
# F-score:  0.42795513373597927
# Precision: 0.31273644388398486 	 Recall:  0.6775956284153005
#
#
# [(3000.0, 'get'), (232886.0, 'HomeControllerHome')]
# F-score:  0.4339788732394367
# Precision: 0.32012987012987015 	 Recall:  0.6734972677595629
#
#
# [(3000.0, 'get'), (232886.0, 'HomeControllerHome')]
# F-score:  0.4339788732394367
# Precision: 0.32012987012987015 	 Recall:  0.6734972677595629
#
#
# [(3000.0, 'get'), (246462.0, 'HomeControllerHome')]
# F-score:  0.43608340888485947
# Precision: 0.32632293080054275 	 Recall:  0.657103825136612
#
#
# [(3000.0, 'get'), (246462.0, 'HomeControllerHome')]
# F-score:  0.43608340888485947
# Precision: 0.32632293080054275 	 Recall:  0.657103825136612
#
#
# [(3000.0, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.4451923076923077
# Precision: 0.3434718100890208 	 Recall:  0.6325136612021858
#
#
# [(3000.0, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.4451923076923077
# Precision: 0.3434718100890208 	 Recall:  0.6325136612021858
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673

# %%
solutions = sorted([(computeFMeasure(ind), *computePrecRec(ind), denormalize(ind)) for ind in res],
                    key=lambda x:x[0])

for f, prec, rec, sol in solutions:
    print (sol)
    print('F-score: ',f)
    print('Precision:',prec, '\t Recall: ', rec, '\n\n')
# Out:
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
#
#
# [(1800.0000000000002, 'get'), (276232.0, 'HomeControllerHome')]
# F-score:  0.44863883847549907
# Precision: 0.30548690064260997 	 Recall:  0.8442622950819673
